# %% [markdown]
# # step 3 -  importing the combined dataframe from the pickle file

# %%
# 3.1 Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# 3.2  Importing tables - orders_products_combined.pkl

# %%
path = r'C:\Users\Lenovo\Instacart Basket Analysis'

# %%
df_ord_prod_comb = pd.read_pickle(os.path.join (path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # step 4 - Checking the shape of the imported dataframe

# %%
# 4.1 Checking output

# %%
df_ord_prod_comb.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_day_of_week  \
# 0           0   2539329        1    prior             1                  2
# 1           0   2539329        1    prior             1                  2
# 2           0   2539329        1    prior             1                  2
# 3           0   2539329        1    prior             1                  2
# 4           0   2539329        1    prior             1                  2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# ...

# %%
df_ord_prod_comb.shape
# Out:
# (32434489, 12)

# %% [markdown]
# # step 5 - Determinig a suitable way to combine the combined dataframe with the products data set

# %%
# Importing tables - products_checked.csv

# %%
df_prod_chec = pd.read_csv(os.path.join (path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_prod_chec.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prod_chec.shape
# Out:
# (49677, 6)

# %%
# formula: df_full_merge = df_ord_prod_comb.merge(df_prod_chec, on = ['product_id'], indicator = True), returns error

# %%
# dropping _merge_
df_ord_prod_comb = df_ord_prod_comb.drop(columns = ['_merge'])

# %%
df_full_merge = df_ord_prod_comb.merge(df_prod_chec, on = ['product_id'], indicator = True)

# %%
df_full_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_day_of_week  \
# 0             0   2539329        1    prior             1                  2
# 1             1   2398795        1    prior             2                  3
# 2             2    473747        1    prior             3                  3
# 3             3   2254736        1    prior             4                  4
# 4             4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
df_full_merge.shape
# Out:
# (32406041, 17)

# %% [markdown]
# # step 6 - Confirming the results of the merge using the merge flag

# %%
# Testing merge without overwriting
pd.merge(df_ord_prod_comb,df_prod_chec, on = ['product_id'], indicator = True)
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                    0   2539329        1    prior             1
# 1                    1   2398795        1    prior             2
# 2                    2    473747        1    prior             3
# 3                    3   2254736        1    prior             4
# 4                    4    431534        1    prior             5
# ...                ...       ...      ...      ...           ...
# 32406036       3360493   1320836   202557    prior            17
# 32406037       3360494     31526   202557    prior            18
# 32406038       3376038    758936   203436    prior             1
# 32406039       3376039   2745165   203436    prior             2
# 32406040       3408036   3093936   205420    prior             1
#
#           order_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     NaN
# ...

# %%
# summing up all the values in the “_merge” column

# %%
df_full_merge['_merge'].value_counts()
# Out:
# both          32406041
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # step 7 - Exporting the newly created dataframe in a suitable format

# %%
# Exporting new dataframe as pickle (due to the size)

# %%
df_full_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
